# %%
# librerías a utilizar
import numpy as np 
import pandas as pd
import datetime as datetime

# plots
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline

# %%
# cargamos los datos
events = pd.read_csv('events.csv', low_memory = False)
events.head()
# Out:
#              timestamp            event    person                        url  \
# 0  2018-05-31 23:38:05  ad campaign hit  0004b0a2  /comprar/iphone/iphone-5s
# 1  2018-05-31 23:38:05     visited site  0004b0a2                        NaN
# 2  2018-05-31 23:38:09   viewed product  0004b0a2                        NaN
# 3  2018-05-31 23:38:40         checkout  0004b0a2                        NaN
# 4  2018-05-29 13:29:25   viewed product  0006a21a                        NaN
#
#        sku              model condition storage           color skus  \
# 0      NaN                NaN       NaN     NaN             NaN  NaN
# 1      NaN                NaN       NaN     NaN             NaN  NaN
# 2   2694.0          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 3   2694.0          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 4  15338.0  Samsung Galaxy S8       Bom    64GB         Dourado  NaN
#
#          ...        search_engine channel new_vs_returning        city  \
# ...

# %%
# busco los principales OS
os_events = events.groupby('operating_system_version').agg({'event':'count'}).sort_values(by='event',ascending = False)[:15]
os_events.reset_index(inplace = True)
os_events
# Out:
#    operating_system_version  event
# 0                Windows 7   19675
# 1               Windows 10   17110
# 2                 Android 7   9964
# 3             Android 6.0.1   7805
# 4                 Android 6   6871
# 5             Android 5.1.1   4123
# 6             Android 7.1.1   3325
# 7              Windows 8.1    2781
# 8             Android 5.0.2   1640
# 9             Android 4.4.2   1402
# 10                 iOS 11.3   1345
# 11            Android 4.4.4   1288
# 12              Android 5.1   1269
# 13                Android 8    973
# 14            Android 5.0.1    746

# %%
g = sns.barplot((x=  categories_sucessfulcategorie .values, y=categories_sucessful.index)
g.set_title("Projects exitosos por categoria", fontsize=15)
g.set_xlabel("Total de proyectos exitosos", fontsize=12)
g.set_ylabel("Nombre de categoria", fontsize=12)
