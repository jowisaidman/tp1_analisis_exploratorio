# %% [markdown]
# ## En este notebook vamos a analizar el comportamiento de los usuarios y sus actividades dentro de la pagina.

# %%
#Inlcuimos las librerias que vamos a utilizar
import numpy as np 
import pandas as pd
import datetime as datetime

# plots
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline

# %%
#Cargamos los datos
events = pd.read_csv('events.csv', low_memory = False)

# %%
#categorizamos
events['timestamp'] = pd.to_datetime(events['timestamp'], errors = 'coerce', format= '%Y-%m-%d')
events['event'] = events['event'].astype('category')

# %%
events['person'].isnull().value_counts()
# Out:
# False    1011288
# Name: person, dtype: int64

# %%
events.groupby('person')['event'].value_counts().sort_values(ascending = False).head(10)
# Out:
# person    event
# 2d5a84c1  viewed product    1525
# 3e34b3cf  viewed product    1487
# 3b5a5833  viewed product    1383
# 71492f2b  viewed product    1364
# d7e60792  viewed product    1212
# cd6e0b8d  viewed product    1174
# 71492f2b  brand listing     1149
# 6b07be7b  viewed product    1118
# 285101a1  viewed product    1077
# c501ff3a  viewed product    1003
# Name: event, dtype: int64

# %%
events['event'].value_counts()
# Out:
# viewed product       528931
# brand listing         98635
# visited site          87378
# ad campaign hit       82827
# generic listing       67534
# searched products     56073
# search engine hit     50957
# checkout              33735
# staticpage             3598
# conversion             1172
# lead                    448
# Name: event, dtype: int64

# %%
lead_person_model = events.loc[events['event'] == 'lead',['event','person','model']]
lead_person_model['person_model'] = lead_person_model['person'] + '_' + lead_person_model['model'] 
lead_person_model
# Out:
#         event    person                            model  \
# 3248     lead  01139919              Samsung Galaxy On 7
# 6636     lead  01bca043                    iPhone 6 Plus
# 7036     lead  01db2fe6                Samsung Galaxy J5
# 13041    lead  03767f8e                         iPhone 6
# 14203    lead  03bdcd81           Samsung Galaxy S7 Edge
# 14523    lead  03d11a48           Samsung Galaxy S7 Edge
# 19432    lead  053e3907                    iPhone 6 Plus
# 19752    lead  055142e0              Samsung Galaxy On 7
# 19898    lead  055142e0              Samsung Galaxy On 7
# 29375    lead  07cd981f                        iPhone 6S
# 31068    lead  087313b9            Motorola Moto G5 Plus
# 32895    lead  0928c785                        iPhone 4G
# 34715    lead  09eabaa9              iPad Air Wi-Fi + 4G
# 34759    lead  09eabaa9              iPad Air Wi-Fi + 4G
# 34774    lead  09eabaa9             iPad Mini Wi-Fi + 4G
# ...

# %%
checkouts_person_model = events.loc[events['event'] == 'checkout',['event','person','model']]
checkouts_person_model['lead'] = checkouts_person_model['person'].isin(lead_person_model['person'])
checkouts_person_model_true = checkouts_person_model.loc[checkouts_person_model['lead'] == True]
# checkouts_person_model_true['person_model'] = checkouts_person_model_true['person'] + '_' + checkouts_person_model_true['model'] 
# checkouts_person_model_true['person_model_lead'] = checkouts_person_model_true['person_model'].isin(lead_person_model['person_model'])
# checkouts_person_model_true = checkouts_person_model_true.loc[checkouts_person_model_true['person_model_lead'] == True]
checkouts_person_model_true
# Out:
#             event    person                                model  lead
# 3367     checkout  01139919    Samsung Galaxy Gran Prime Duos TV  True
# 3442     checkout  01139919                            iPhone 4S  True
# 3458     checkout  01139919                            iPhone 4G  True
# 3629     checkout  01139919                            iPhone 4S  True
# 6691     checkout  01bca043                            iPhone 6S  True
# 6984     checkout  01db2fe6                    Samsung Galaxy J5  True
# 6986     checkout  01db2fe6                    Samsung Galaxy J5  True
# 7067     checkout  01db2fe6                    Samsung Galaxy A5  True
# 7127     checkout  01db2fe6                    Samsung Galaxy J5  True
# 7156     checkout  01db2fe6                    Samsung Galaxy J5  True
# 13042    checkout  03767f8e                             iPhone 6  True
# 13044    checkout  03767f8e                            iPhone 5s  True
# ...

# %%
# checkouts_person_model = checkouts.groupby(['person','model'])['person','model']
# checkouts_person_model['model'].drop_duplicates()

# %%
lead_person_model.groupby('person')['person','model'].head()
# Out:
#            person                            model
# 3248     01139919              Samsung Galaxy On 7
# 6636     01bca043                    iPhone 6 Plus
# 7036     01db2fe6                Samsung Galaxy J5
# 13041    03767f8e                         iPhone 6
# 14203    03bdcd81           Samsung Galaxy S7 Edge
# 14523    03d11a48           Samsung Galaxy S7 Edge
# 19432    053e3907                    iPhone 6 Plus
# 19752    055142e0              Samsung Galaxy On 7
# 19898    055142e0              Samsung Galaxy On 7
# 29375    07cd981f                        iPhone 6S
# 31068    087313b9            Motorola Moto G5 Plus
# 32895    0928c785                        iPhone 4G
# 34715    09eabaa9              iPad Air Wi-Fi + 4G
# 34759    09eabaa9              iPad Air Wi-Fi + 4G
# 34774    09eabaa9             iPad Mini Wi-Fi + 4G
# 35050    0a0393a5                         iPhone 8
# 49030    0e31e9eb                         iPhone 8
# ...
